# %%
import os 
from pathlib import Path
import logging

# basicConfig sets up the "rules" for your log
logging.basicConfig(level=logging.INFO, format='[%(asctime)s]:%(message)s:')

#Crete a folder for project
project_name='ML_Projects'

list_of_files=[
    f"src/{project_name}/__init__.py",
    f"src/{project_name}/components/__init__.py",
    f"src/{project_name}/utils/__init__.py",
    f"src/{project_name}/utils/common.py",
    f"src/{project_name}/config/__init__.py",
    f"src/{project_name}/config/configuration.py",
    f"src/{project_name}/pipeline/__init__.py",
    f"src/{project_name}/entity/__init__.py",
    f"src/{project_name}/entity/config_entity.py",
    f"src/{project_name}/constants/__init__.py",
    "config/config.yaml",
    "params.yaml",
    "schema.yaml",
    "main.py",
    "app.py",
    "requirements.txt",
    "setup.py",
    "research/trails.ipynb",
    "templates/index.html"
    
]


for filepath in list_of_files:
    filepath=Path(filepath)

    filedir,filename= os.path.split(filepath)

    if filedir !="":
        os.makedirs(filedir,exist_ok=True)
        logging.info(f"Creating directory ; {filedir} for the file : {filename}")
    if (not os.path.exists(filepath)) or (os.path.getsize(filepath)==0):
        with open(filepath,"w") as f:
            pass
            logging.info(f"Creating empty file : {filepath}")
    else:
        logging.info(f"{filename} is already exists")
# Out:
# [2025-12-22 05:49:07,601]:Creating directory ; src\ML_Projects for the file : __init__.py:
# [2025-12-22 05:49:07,602]:Creating empty file : src\ML_Projects\__init__.py:
# [2025-12-22 05:49:07,604]:Creating directory ; src\ML_Projects\components for the file : __init__.py:
# [2025-12-22 05:49:07,606]:Creating empty file : src\ML_Projects\components\__init__.py:
# [2025-12-22 05:49:07,607]:Creating directory ; src\ML_Projects\utils for the file : __init__.py:
# [2025-12-22 05:49:07,609]:Creating empty file : src\ML_Projects\utils\__init__.py:
# [2025-12-22 05:49:07,611]:Creating directory ; src\ML_Projects\utils for the file : common.py:
# [2025-12-22 05:49:07,612]:Creating empty file : src\ML_Projects\utils\common.py:
# [2025-12-22 05:49:07,614]:Creating directory ; src\ML_Projects\config for the file : __init__.py:
# [2025-12-22 05:49:07,616]:Creating empty file : src\ML_Projects\config\__init__.py:
# [2025-12-22 05:49:07,618]:Creating directory ; src\ML_Projects\config for the file : configuration.py:
# [2025-12-22 05:49:07,620]:Creating empty file : src\ML_Projects\config\configuration.py:
# [2025-12-22 05:49:07,624]:Creating directory ; src\ML_Projects\pipeline for the file : __init__.py:
# [2025-12-22 05:49:07,629]:Creating empty file : src\ML_Projects\pipeline\__init__.py:
# [2025-12-22 05:49:07,630]:Creating directory ; src\ML_Projects\entity for the file : __init__.py:
# [2025-12-22 05:49:07,632]:Creating empty file : src\ML_Projects\entity\__init__.py:
# [2025-12-22 05:49:07,634]:Creating directory ; src\ML_Projects\entity for the file : config_entity.py:
# [2025-12-22 05:49:07,637]:Creating empty file : src\ML_Projects\entity\config_entity.py:
# [2025-12-22 05:49:07,639]:Creating directory ; src\ML_Projects\constants for the file : __init__.py:
# [2025-12-22 05:49:07,639]:Creating empty file : src\ML_Projects\constants\__init__.py:
# [2025-12-22 05:49:07,643]:Creating directory ; config for the file : config.yaml:
# [2025-12-22 05:49:07,646]:Creating empty file : config\config.yaml:
# [2025-12-22 05:49:07,648]:Creating empty file : params.yaml:
# [2025-12-22 05:49:07,650]:Creating empty file : schema.yaml:
# [2025-12-22 05:49:07,651]:Creating empty file : main.py:
# [2025-12-22 05:49:07,654]:Creating empty file : app.py:
# [2025-12-22 05:49:07,654]:Creating empty file : requirements.txt:
# [2025-12-22 05:49:07,654]:Creating empty file : setup.py:
# [2025-12-22 05:49:07,654]:Creating directory ; research for the file : trails.ipynb:
# [2025-12-22 05:49:07,661]:Creating empty file : research\trails.ipynb:
# [2025-12-22 05:49:07,663]:Creating directory ; templates for the file : index.html:
# [2025-12-22 05:49:07,665]:Creating empty file : templates\index.html:
